# %% [markdown]
# <a href="https://colab.research.google.com/github/RESHMA-PARVEEN/r170345/blob/main/3dplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.cm as cm

plt.gca(projection='3d')
#vector plot
x=np.linspace(-10,10,5)
y=np.linspace(-10,10,5)
z=np.linspace(-10,10,5)
xv, yv, zv = np.meshgrid(x,y,z)
plt.quiver(xv, yv, zv, -xv, -yv, -zv)
plt.savefig("vector3d.pdf")
plt.show()
